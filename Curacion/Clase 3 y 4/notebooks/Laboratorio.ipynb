# %% [markdown]
# ### Laboratorio

# %%
import pandas as pd

# %%
permisos_SF = pd.read_csv("../input/Permisos_SF/Building_Permits.csv")
permisos_SF
# Out:
# /home/mgonella/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# 5       201706149344            8            otc alterations permit
# 6       201706300814            8            otc alterations permit
# 7            M803667            8            otc alterations permit
# 8            M804227            8            otc alterations permit
# ...

# %%
# Set seed for reproducibility
import numpy as np
np.random.seed(0)

# %%
permisos_SF.sample(5)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 40553   201403039652            8            otc alterations permit
# 169731  201510159735            3  additions alterations or repairs
# 19180        M409787            8            otc alterations permit
# 68047   201411191888            8            otc alterations permit
# 64238        M527228            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 40553            03/03/2014  3732  008            400                  NaN
# 169731           10/15/2015  2609  028             79                  NaN
# 19180            07/22/2013  4624  031            178                  NaN
# 68047            11/19/2014  0039  109            294                  NaN
# 64238            10/14/2014  1251  002            707                  NaN
#
#         Street Name Street Suffix      ...        Existing Construction Type  \
# ...

# %%
pd.DataFrame([["Permit Number", "No description provided", "String"],
["Permit Type", "No description provided", "Numeric"],
["Permit Type Definition", "No description provided", "String"],
["Permit Creation Date", "No description provided", "DateTime"],
["Block", "No description provided", "String"],
["Lot", "No description provided", "String"], 
["Street Number", "No description provided", "Numeric"],
["Street Number Suffix", "No description provided", "String"],
["Street Name", "No description provided", "String"],
["Street Suffix", "No description provided", "String"],
["Unit", "No description provided", "String"],
["Unit Suffix", "No description provided", "String"],         
["Description", "No description provided", "String"],
["Current Status", "No description provided", "String"],
["Current Status Date", "No description provided", "DateTime"],       
["Filed Date", "No description provided", "DateTime"],
["Issued Date", "No description provided", "String"],
["Completed Date", "No description provided", "String"],    
["First Construction Document Date", "No description provided", "String"],
["Structural Notification", "No description provided", "String"],
["Number of Existing Stories", "No description provided", "String"],
["Number of Proposed Stories", "No description provided", "String"],
["Voluntary Soft-Story Retrofit", "No description provided", "String"],
["Fire Only Permit", "No description provided", "String"],    
["Permit Expiration Date", "No description provided", "String"],                   
["Estimated Cost", "No description provided", "String"],
["Revised Cost", "No description provided", "String"],
["Existing Use", "No description provided", "String"],
["Existing Units", "No description provided", "String"],
["Proposed Use", "No description provided", "String"],    
["Proposed Units", "No description provided", "String"],
["Plansets", "No description provided", "String"],
["TIDF Compliance", "No description provided", "String"],  
["Existing Construction Type", "No description provided", "String"],
["Existing Construction Type Description", "No description provided", "String"],
["Proposed Construction Type", "No description provided", "String"],              
["Proposed Construction Type Description", "No description provided", "String"],
["Site Permit", "No description provided", "String"],
["Supervisor District", "No description provided", "Numeric"],
["Neighborhoods - Analysis Boundaries", "No description provided", "String"],
["Zipcode", "No description provided", "Numeric"],
["Location", "No description provided", "String"],
["Record ID", "No description provided", "Numeric"]], columns=["Field name","Field description", "Type"])
# Out:
#                                 Field name        Field description      Type
# 0                            Permit Number  No description provided    String
# 1                              Permit Type  No description provided   Numeric
# 2                   Permit Type Definition  No description provided    String
# 3                     Permit Creation Date  No description provided  DateTime
# 4                                    Block  No description provided    String
# 5                                      Lot  No description provided    String
# 6                            Street Number  No description provided   Numeric
# 7                     Street Number Suffix  No description provided    String
# 8                              Street Name  No description provided    String
# 9                            Street Suffix  No description provided    String
# 10                                    Unit  No description provided    String
# ...

# %%
permisos_SF.dtypes
# Out:
# Permit Number                              object
# Permit Type                                 int64
# Permit Type Definition                     object
# Permit Creation Date                       object
# Block                                      object
# Lot                                        object
# Street Number                               int64
# Street Number Suffix                       object
# Street Name                                object
# Street Suffix                              object
# Unit                                      float64
# Unit Suffix                                object
# Description                                object
# Current Status                             object
# Current Status Date                        object
# Filed Date                                 object
# Issued Date                                object
# Completed Date                             object
# First Construction Document Date           object
# ...

# %%
permisos_SF.describe(include='all')
# Out:
#        Permit Number    Permit Type  Permit Type Definition  \
# count         198900  198900.000000                  198900
# unique        181495            NaN                       8
# top     201602179765            NaN  otc alterations permit
# freq             101            NaN                  178844
# mean             NaN       7.522323                     NaN
# std              NaN       1.457451                     NaN
# min              NaN       1.000000                     NaN
# 25%              NaN       8.000000                     NaN
# 50%              NaN       8.000000                     NaN
# 75%              NaN       8.000000                     NaN
# max              NaN       8.000000                     NaN
#
#        Permit Creation Date   Block     Lot  Street Number  \
# count                198900  198900  198900  198900.000000
# unique                 1291    4896    1055            NaN
# top              09/15/2017    3708     001            NaN
# ...

# %%
permisos_SF = pd.read_csv("../input/Permisos_SF/Building_Permits.csv", 
                               parse_dates=["Permit Creation Date","Current Status Date", "Filed Date"])
permisos_SF.dtypes
# Out:
# /home/mgonella/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Permit Number                                     object
# Permit Type                                        int64
# Permit Type Definition                            object
# Permit Creation Date                      datetime64[ns]
# Block                                             object
# Lot                                               object
# Street Number                                      int64
# Street Number Suffix                              object
# Street Name                                       object
# Street Suffix                                     object
# Unit                                             float64
# Unit Suffix                                       object
# ...

# %%
permisos_SF.describe(include='all')
# Out:
#        Permit Number    Permit Type  Permit Type Definition  \
# count         198900  198900.000000                  198900
# unique        181495            NaN                       8
# top     201602179765            NaN  otc alterations permit
# freq             101            NaN                  178844
# first            NaN            NaN                     NaN
# last             NaN            NaN                     NaN
# mean             NaN       7.522323                     NaN
# std              NaN       1.457451                     NaN
# min              NaN       1.000000                     NaN
# 25%              NaN       8.000000                     NaN
# 50%              NaN       8.000000                     NaN
# 75%              NaN       8.000000                     NaN
# max              NaN       8.000000                     NaN
#
#        Permit Creation Date   Block     Lot  Street Number  \
# count                198900  198900  198900  198900.000000
# ...

# %%
permisos_SF.shape
# Out:
# (198900, 43)

# %%
permisos_SF = pd.read_csv("../input/Permisos_SF/Building_Permits.csv", 
                               parse_dates=["Permit Creation Date","Current Status Date", "Filed Date"],
                               index_col=['Permit Number'])
# Out:
# /home/mgonella/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
permisos_SF
# Out:
#                Permit Type            Permit Type Definition  \
# Permit Number
# 201505065519             4                      sign - erect
# 201604195146             4                      sign - erect
# 201605278609             3  additions alterations or repairs
# 201611072166             8            otc alterations permit
# 201611283529             6                       demolitions
# 201706149344             8            otc alterations permit
# 201706300814             8            otc alterations permit
# M803667                  8            otc alterations permit
# M804227                  8            otc alterations permit
# M804767                  8            otc alterations permit
# M805287                  8            otc alterations permit
# M805907                  8            otc alterations permit
# M806447                  8            otc alterations permit
# 201707252846             8            otc alterations permit
# ...

# %%
permisos_SF.shape
# Out:
# (198900, 42)

# %%
permisos_SF[permisos_SF.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 42 columns]
